# %%
import h5py 
import matplotlib.pyplot as plt

# %%
f='default.hdf'
df=h5py.File(f,'r')
for key in df.keys():
    print (key)
# Out:
# command_line_arguments
# injection_parameters
# injection_samples
# noise_samples
# normalization_parameters
# static_arguments

# %%
print (df["injection_samples"].keys())

print (df["injection_parameters"].keys())

print (df["injection_parameters"]['mass1'].value)
# Out:
# <KeysViewHDF5 ['event_time', 'h1_strain', 'l1_strain']>
# <KeysViewHDF5 ['coa_phase', 'dec', 'h1_signal', 'h1_snr', 'inclination', 'injection_snr', 'l1_signal', 'l1_snr', 'mass1', 'mass2', 'polarization', 'ra', 'scale_factor', 'spin1z', 'spin2z']>
# [36.21780832 11.4409146  52.82970263 52.52813963 18.54267644 77.87092394
#  37.20741028 64.05713385 70.41723981 18.37159722 12.200043   30.2826017
#  66.52081086 39.21877022 77.37131065 73.57861202 35.74481929 57.42950533
#  33.87464457 16.51719375 54.94221523 48.41136526 56.03290246 65.63679125
#  75.8321009  30.61142244 53.05050587 66.65528088 72.30037393 12.1350175
#  13.61772048 40.72799945]
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/site-packages/ipykernel/__main__.py:5: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.

# %%
a = df["injection_samples"]["event_time"].value
b = df["injection_samples"]["h1_strain"].value
# Out:
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/site-packages/ipykernel/__main__.py:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if __name__ == '__main__':
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/site-packages/ipykernel/__main__.py:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   from ipykernel import kernelapp as app

# %%
plt.plot(a,b)
plt.show()

# %%
print (b)
# Out:
# [[ 37.40263    -7.1099477  10.68551   ...   7.230395  -69.84984
#    18.024542 ]
#  [ -7.1349325  67.10508    42.558968  ...  51.428173   49.747963
#   -14.098332 ]
#  [-70.61765    -8.3724575 -43.89524   ... -21.035694   39.862732
#   -13.540668 ]
#  ...
#  [-23.165209   46.825535   22.328012  ...  34.828335   20.792225
#    47.12176  ]
#  [ -3.5969474 -32.73976    -8.634732  ...  11.141791  -26.766966
#    16.298914 ]
#  [-21.961555  -77.97544    11.991275  ... -40.991505  -80.65208
#    66.360115 ]]
